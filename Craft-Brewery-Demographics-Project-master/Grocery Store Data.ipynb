# %%
import pandas as pd
import numpy as np
import requests
import json


# Google developer API key
from config import apikey

# %%
cityname = []
groceryname = []
address = []

# %%
target_coordinates = [("29.7604, -95.3698"), ("29.4241, -98.4936")]
target_search = "grocery"
target_radius = 500
target_type = "retail"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": apikey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.7571612,
#                     "lng": -95.36876319999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.75847882989272,
#                         "lng": -95.36743827010727
#                     },
#                     "southwest": {
#                         "lat": 29.75577917010727,
#                         "lng": -95.37013792989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "02170dc2fd1682e2b79e98ac97ef905d6401467f",
#             "name": "Houston Underground Walking Tunnel System",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJxY99aTm_QIYRWPzIktUaEDs",
#             "plus_code": {
#                 "compound_code": "QJ4J+VF Downtown, Houston, TX",
#                 "global_code": "76X6QJ4J+VF"
#             },
#             "rating": 0,
#             "reference": "CmRbAAAAkDLBkYlULoELsC_BhHc9oX3bqpIHgQzFFYB8jJFr_faNJu_2j1iHbZj48WJ9Tde2NS3TMXOX5D_fpbq0NGgrEa4uUDWS5A3ayN4YGwj_nuSg1tV9SwD1w3A3goyBebnzEhCzxI-B6gE6vtRNgpPSeVygGhRkCE_7lkKEEtzgxvSAwdx9xg5kYQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "supermarket",
#                 "grocery_or_supermarket",
#                 "store",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "601-699 Dallas St, Houston"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.7584166,
#                     "lng": -95.3683009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.75962242989272,
#                         "lng": -95.36671452010728
#                     },
#                     "southwest": {
#                         "lat": 29.75692277010728,
#                         "lng": -95.36941417989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "0eeed44d87001f146684909f866c04f1c418cf1e",
#             "name": "Uptown Express Deli",
#             "place_id": "ChIJMwExfzm_QIYRMEbN2LQMEfE",
#             "plus_code": {
#                 "compound_code": "QJ5J+9M Downtown, Houston, TX",
#                 "global_code": "76X6QJ5J+9M"
#             },
#             "rating": 5,
#             "reference": "CmRbAAAAZIdSqgw5IagoqmgnDTujyaSCq9Vlk9hb8H1IVJfbG687K9CdvvFFXd799U-Yxqc3vbRocwoAbrP4QV2ZB7pQOCE-sOvIQhPdaasfhRD1WV4s8aWXH2U8MBr93uchXcS1EhBwIEUrojBGWRpX8VU4QBscGhSOSW3Tt-EbIt1YxzAhxHV54CkWRw",
#             "scope": "GOOGLE",
#             "types": [
#                 "grocery_or_supermarket",
#                 "store",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1000 Louisiana St # 100, Houston"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.755205,
#                     "lng": -95.363393
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.75655482989272,
#                         "lng": -95.36204317010728
#                     },
#                     "southwest": {
#                         "lat": 29.75385517010728,
#                         "lng": -95.36474282989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "bd37fa4e0f5bd2c5596b52ca7ddbb65485b64483",
#             "name": "Gateway Newstands",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103978946295494757009/photos\">Gateway Newsstands</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAw5Z-NoYPw1qtv0DUPLuFg73lWJ0n3TqcmY9pFvAxKqenLq4TK_yyy_SCb19k0vfhq--xS_xdlo75iaZzqp-gX7hXG7gfs3n6D8CXEC4Edfg4K6BmAg7l8sRgU1oyhxZ3EhDyiMRnnSW-CGsko0YSNk4iGhQxPeR30b8fRs963YLWPb4KZfEv1g",
#                     "width": 1368
#                 }
#             ],
#             "place_id": "ChIJ0Ws6SCO_QIYR6pCpiiDC89k",
#             "plus_code": {
#                 "compound_code": "QJ4P+3J Downtown, Houston, TX",
#                 "global_code": "76X6QJ4P+3J"
#             },
#             "rating": 0,
#             "reference": "CmRbAAAA2g1Ww7nIsDqzhC7Gx9AspeuVFOe6rRU3vgGtrUsVmfZfTVn3XDQbt3LgvVIxY6bvUT2GCinZb_rZGkfy5jUBsauT3FBiacM5odicLOBlL49IVHXo6l0yYX9UbFNUOIT5EhC6b7jqMTdD7nCdRz0vUWzpGhQ0KmMXOOT8yaTyOTvSH9qu0P8SOg",
#             "scope": "GOOGLE",
#             "types": [
#                 "convenience_store",
#                 "grocery_or_supermarket",
#                 "book_store",
#                 "finance",
#                 "store",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1200 McKinney St # 406, Houston"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 29.755938,
#                     "lng": -95.36545199999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.75733067989272,
#                         "lng": -95.36417422010727
#                     },
#                     "southwest": {
#                         "lat": 29.75463102010728,
#                         "lng": -95.36687387989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "ff165dfd9e3537ff500a7947487942b927be9569",
#             "name": "Main Food Store",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2576,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110001799767989082887/photos\">Abimael Reyes</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA8vpZNIPMr-ujwBgYZY3oeoc6Ceu3SJxRe2EXysjdiE5kMz8CqtUMV0R__v2XNRGcUJKBxzi18S7eAiHxc6z61IR74t5iZaDUHJAPGpD-obHMs4lU--V0ofpQOm6OknPXEhCJYfTN5LkC96LDbFIzKhrbGhTRBDT4Ma92knGdLdo8TRt5ezIwXA",
#                     "width": 1932
#                 }
#             ],
#             "place_id": "ChIJb-k2gTu_QIYR5guIzZVtGUw",
#             "plus_code": {
#                 "compound_code": "QJ4M+9R Downtown, Houston, TX",
#                 "global_code": "76X6QJ4M+9R"
#             },
#             "rating": 3,
#             "reference": "CmRbAAAAsZqfOidXyQv2lPzHe5pF-j22kKo2csiEOgSVil40X7co8UgB3Gkj81yPm9togrgX4lq2Dysu5sv8VjzRIoTRdV5L66dD55xSzLksGhsJNHxPOfYAvcB2NhZf67ezYL4nEhC0vmKM9KK2vK6Gqr1YZv_9GhS7f0SePW0rD9Tq6OUuTK4qqfUz_A",
#             "scope": "GOOGLE",
#             "types": [
#                 "convenience_store",
#                 "store",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1101 S Main St, Houston"
#         }
#     ],
#     "status": "OK"
# }

# %%
grocerypd = pd.DataFrame({'City Name': cityname,'Grocery Name': groceryname,'Address': address})
grocerypd
# Out:
# Empty DataFrame
# Columns: [Address, City Name, Grocery Name]
# Index: []

# %%
print(f"Begin API calls")
print(f"---------------")
